# %%
# !pip install networkx
# !pip install python-louvain
# !pip install matplotlib
# !pip install xlrd
# !pip install scipy
# Out:
# Requirement already satisfied: networkx in c:\users\toshiba\envs\test\lib\site-packages (3.1)
# Requirement already satisfied: python-louvain in c:\users\toshiba\envs\test\lib\site-packages (0.16)
# Requirement already satisfied: networkx in c:\users\toshiba\envs\test\lib\site-packages (from python-louvain) (3.1)
# Requirement already satisfied: numpy in c:\users\toshiba\envs\test\lib\site-packages (from python-louvain) (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\toshiba\envs\test\lib\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\toshiba\envs\test\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\toshiba\envs\test\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\toshiba\envs\test\lib\site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\toshiba\envs\test\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\toshiba\envs\test\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\toshiba\envs\test\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\toshiba\envs\test\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\toshiba\envs\test\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\toshiba\envs\test\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\toshiba\envs\test\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: xlrd in c:\users\toshiba\envs\test\lib\site-packages (2.0.1)
# Requirement already satisfied: scipy in c:\users\toshiba\envs\test\lib\site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in c:\users\toshiba\envs\test\lib\site-packages (from scipy) (1.24.3)

# %%
# importing networkx
import networkx as nx
# importing matplotlib.pyplot
import matplotlib.pyplot as plt
import xlrd

file ="C:\\Users\\Toshiba\\ijaz\\dataset\\dataset1.xls"


G=nx.Graph()

names=[]

book= xlrd.open_workbook(file)

sheet = book.sheet_by_index(0)

for row in range(sheet.nrows):
    data = sheet.row_slice(row)
    
    person1 = data[0].value
    person2 = data[1].value
    
    names.append((person1, person2))

G.add_edges_from(names)

nx.draw(G)
plt.show()
plt.savefig("C:\\Users\\Toshiba\\ijaz\\diagrams\\dataset1-graph.png")

# %%
# importing networkx
import networkx as nx
# importing matplotlib.pyplot
import matplotlib.pyplot as plt
import xlrd

file ="C:\\Users\\Toshiba\\ijaz\\dataset\\dataset1.xls"


G=nx.DiGraph()

names=[]

book= xlrd.open_workbook(file)

sheet = book.sheet_by_index(0)

for row in range(sheet.nrows):
    data = sheet.row_slice(row)
    
    person1 = data[0].value
    person2 = data[1].value
    
    names.append((person1, person2))

G.add_edges_from(names)

nx.draw(G)
plt.show()
plt.savefig("C:\\Users\\Toshiba\\ijaz\\diagrams\\dataset1-digraph.png")

# %%
# importing networkx
import networkx as nx
# importing matplotlib.pyplot
import matplotlib.pyplot as plt
import xlrd

file ="C:\\Users\\Toshiba\\ijaz\\dataset\\dataset1.xls"


G=nx.MultiGraph()

names=[]

book= xlrd.open_workbook(file)

sheet = book.sheet_by_index(0)

for row in range(sheet.nrows):
    data = sheet.row_slice(row)
    
    person1 = data[0].value
    person2 = data[1].value
    
    names.append((person1, person2))

G.add_edges_from(names)

nx.draw(G)
plt.show()
plt.savefig("C:\\Users\\Toshiba\\ijaz\\diagrams\\dataset1-mulitgraph.png")

# %%
# importing networkx
import networkx as nx
# importing matplotlib.pyplot
import matplotlib.pyplot as plt
import xlrd

file ="C:\\Users\\Toshiba\\ijaz\\dataset\\dataset1.xls"


G=nx.MultiDiGraph()

names=[]

book= xlrd.open_workbook(file)

sheet = book.sheet_by_index(0)

for row in range(sheet.nrows):
    data = sheet.row_slice(row)
    
    person1 = data[0].value
    person2 = data[1].value
    
    names.append((person1, person2))

G.add_edges_from(names)

nx.draw(G)
plt.show()
plt.savefig("C:\\Users\\Toshiba\\ijaz\\diagrams\\dataset1-multidigraph.png")

# %% [markdown]
# # Centrality Measures

# %% [markdown]
# # Graph1

# %%
import networkx as nx
import pandas as pd

# Assuming your data is stored in a DataFrame with four columns: source, target, attribute1, attribute2
data = pd.read_excel(file)

# Create an empty graph
G = nx.Graph()

# Add nodes from the source and target columns
G.add_nodes_from(data['col1'])
G.add_nodes_from(data['col2'])

# Add edges from the source and target columns
edges = zip(data['col3'], data['col4'])
G.add_edges_from(edges)

# Compute degree centrality measures
degree_centrality = nx.degree_centrality(G)
# degree_centrality

df = pd.DataFrame(list(centrality_measures.items()), columns=['col1', 'col2','col3'])

# Display the DataFrame
df.to_excel('C:\\Users\\Toshiba\\ijaz\\centrality_files\\degree_centrality.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 5
#       2 import pandas as pd
#       4 # Assuming your data is stored in a DataFrame with four columns: source, target, attribute1, attribute2
# ----> 5 data = pd.read_excel(file)
#       7 # Create an empty graph
#       8 G = nx.Graph()
#
# File ~\Envs\test\lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# File ~\Envs\test\lib\site-packages\pandas\io\excel\_base.py:1496, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1494     ext = "xls"
#    1495 else:
# -> 1496     ext = inspect_excel_format(
#    1497         content_or_path=path_or_buffer, storage_options=storage_options
#    1498     )
#    1499     if ext is None:
#    1500         raise ValueError(
#    1501             "Excel file format cannot be determined, you must specify "
#    1502             "an engine manually."
#    1503         )
#
# File ~\Envs\test\lib\site-packages\pandas\io\excel\_base.py:1371, in inspect_excel_format(content_or_path, storage_options)
#    1368 if isinstance(content_or_path, bytes):
#    1369     content_or_path = BytesIO(content_or_path)
# -> 1371 with get_handle(
#    1372     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1373 ) as handle:
#    1374     stream = handle.handle
#    1375     stream.seek(0)
#
# File ~\Envs\test\lib\site-packages\pandas\io\common.py:868, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#    (...)
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
# --> 868         handle = open(handle, ioargs.mode)
#     869     handles.append(handle)
#     871 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Toshiba\\ijaz\\centrality_files\\betweenness_centrality.xls'

# %%
# importing networkx
import networkx as nx
# importing matplotlib.pyplot
import matplotlib.pyplot as plt
import xlrd

file ="C:\\Users\\Toshiba\\ijaz\\centrality_files\\degree_centrality.xls"


G=nx.Graph()

names=[]

book= xlrd.open_workbook(file)

sheet = book.sheet_by_index(0)

for row in range(sheet.nrows):
    data = sheet.row_slice(row)
    
    person1 = data[0].value
    person2 = data[1].value
    
    names.append((person1, person2))

G.add_edges_from(names)

nx.draw(G)
plt.show()
plt.savefig("C:\\Users\\Toshiba\\ijaz\\centrality_files\\diagrams\\degree_centrality.png")

# %%
# importing networkx
import networkx as nx
# importing matplotlib.pyplot
import matplotlib.pyplot as plt
import xlrd

file ="C:\\Users\\Toshiba\\ijaz\\centrality_files\\betweenness_centrality.xls"


G=nx.Graph()

names=[]

book= xlrd.open_workbook(file)

sheet = book.sheet_by_index(0)

for row in range(sheet.nrows):
    data = sheet.row_slice(row)
    
    person1 = data[0].value
    person2 = data[1].value
    
    names.append((person1, person2))

G.add_edges_from(names)

nx.draw(G)
plt.show()
plt.savefig("C:\\Users\\Toshiba\\ijaz\\centrality_files\\diagrams\\betweenness_centrality.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 14
#      10 G=nx.Graph()
#      12 names=[]
# ---> 14 book= xlrd.open_workbook(file)
#      16 sheet = book.sheet_by_index(0)
#      18 for row in range(sheet.nrows):
#
# File ~\Envs\test\lib\site-packages\xlrd\__init__.py:166, in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#      84 def open_workbook(filename=None,
#      85                   logfile=sys.stdout,
#      86                   verbosity=0,
#    (...)
#      93                   ignore_workbook_corruption=False
#      94                   ):
#      95     """
#      96     Open a spreadsheet file for data extraction.
#      97
#    (...)
#     163     :returns: An instance of the :class:`~xlrd.book.Book` class.
#     164     """
# --> 166     file_format = inspect_format(filename, file_contents)
#     167     # We have to let unknown file formats pass through here, as some ancient
#     168     # files that xlrd can parse don't start with the expected signature.
#     169     if file_format and file_format != 'xls':
#
# File ~\Envs\test\lib\site-packages\xlrd\__init__.py:60, in inspect_format(path, content)
#      58 else:
#      59     path = os.path.expanduser(path)
# ---> 60     with open(path, "rb") as f:
#      61         peek = f.read(PEEK_SIZE)
#      63 if peek.startswith(XLS_SIGNATURE):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Toshiba\\ijaz\\centrality_files\\betweenness_centrality.xls'

# %%
import networkx as nx
import pandas as pd

# Assuming your data is stored in a DataFrame with four columns: source, target, attribute1, attribute2
data = pd.read_excel(file)

# Create an empty graph
G = nx.Graph()

# Add nodes from the source and target columns
G.add_nodes_from(data['col1'])
G.add_nodes_from(data['col2'])

# Add edges from the source and target columns
edges = zip(data['col3'], data['col4'])
G.add_edges_from(edges)

# Compute degree centrality measures
centrality_measures = nx.betweenness_centrality(G)
# centrality_measures

df = pd.DataFrame(list(centrality_measures.items()), columns=['col1', 'col2'])

# Display the DataFrame
df.to_excel('C:\\Users\\Toshiba\\ijaz\\centrality_files\\betweenness_centrality.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 5
#       2 import pandas as pd
#       4 # Assuming your data is stored in a DataFrame with four columns: source, target, attribute1, attribute2
# ----> 5 data = pd.read_excel(file)
#       7 # Create an empty graph
#       8 G = nx.Graph()
#
# File ~\Envs\test\lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# File ~\Envs\test\lib\site-packages\pandas\io\excel\_base.py:1496, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1494     ext = "xls"
#    1495 else:
# -> 1496     ext = inspect_excel_format(
#    1497         content_or_path=path_or_buffer, storage_options=storage_options
#    1498     )
#    1499     if ext is None:
#    1500         raise ValueError(
#    1501             "Excel file format cannot be determined, you must specify "
#    1502             "an engine manually."
#    1503         )
#
# File ~\Envs\test\lib\site-packages\pandas\io\excel\_base.py:1371, in inspect_excel_format(content_or_path, storage_options)
#    1368 if isinstance(content_or_path, bytes):
#    1369     content_or_path = BytesIO(content_or_path)
# -> 1371 with get_handle(
#    1372     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1373 ) as handle:
#    1374     stream = handle.handle
#    1375     stream.seek(0)
#
# File ~\Envs\test\lib\site-packages\pandas\io\common.py:868, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#    (...)
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
# --> 868         handle = open(handle, ioargs.mode)
#     869     handles.append(handle)
#     871 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Toshiba\\ijaz\\centrality_files\\betweenness_centrality.xls'

# %%
import pandas as pd
import networkx as nx

# Load the dataset
df = pd.read_excel(file)

# Create a NetworkX graph
G = nx.from_pandas_edgelist(df, source='col1', target='col2')

# Calculate the k-shell decomposition
core_numbers = nx.core_number(G)

# Calculate and print the k-shell centrality
k_shell_centrality = {}
for node, core_number in core_numbers.items():
    k_shell_centrality[node] = core_number


# Calculate the k-shell decomposition
core_numbers = nx.core_number(G)

# Calculate and print the k-shell centrality
k_shell_centrality = {}
for node, core_number in core_numbers.items():
    k_shell_centrality[node] = core_number
# print("K-Shell Centrality:", k_shell_centrality)


df = pd.DataFrame(list(k_shell_centrality.items()), columns=['col1', 'col2'])

# Display the DataFrame
df.to_excel('C:\\Users\\Toshiba\\ijaz\\centrality_files\\k_shell_centrality.xlsx')

# %%
# importing networkx
import networkx as nx
# importing matplotlib.pyplot
import matplotlib.pyplot as plt
import xlrd

file ="C:\\Users\\Toshiba\\ijaz\\centrality_files\\k_shell_centrality.xls"


G=nx.Graph()

names=[]

book= xlrd.open_workbook(file)

sheet = book.sheet_by_index(0)

for row in range(sheet.nrows):
    data = sheet.row_slice(row)
    
    person1 = data[0].value
    person2 = data[1].value
    
    names.append((person1, person2))

G.add_edges_from(names)

nx.draw(G)
plt.show()
plt.savefig("C:\\Users\\Toshiba\\ijaz\\centrality_files\\diagrams\\k_shell_centrality.png")

# %%
import pandas as pd
import networkx as nx

# Load the dataset
df = pd.read_excel(file)

# Create a NetworkX graph
G = nx.from_pandas_edgelist(df, source='col1', target='col2')

# Calculate and print the eigenvector centrality
centrality_measures = nx.eigenvector_centrality(G, max_iter=1000)  # Increase max_iter value
# print("Eigenvector Centrality:", centrality_measures)

# Implement other centrality measures here...
# centrality_measures

df = pd.DataFrame(list(centrality_measures.items()), columns=['col1', 'col2'])

# Display the DataFrame
df.to_excel('C:\\Users\\Toshiba\\ijaz\\centrality_files\\Eigenvector Centrality.xlsx')

# %%
# importing networkx
import networkx as nx
# importing matplotlib.pyplot
import matplotlib.pyplot as plt
import xlrd

file ="C:\\Users\\Toshiba\\ijaz\\centrality_files\\EigenvectorCentrality.xls"


G=nx.Graph()

names=[]

book= xlrd.open_workbook(file)

sheet = book.sheet_by_index(0)

for row in range(sheet.nrows):
    data = sheet.row_slice(row)
    
    person1 = data[0].value
    person2 = data[1].value
    
    names.append((person1, person2))

G.add_edges_from(names)

nx.draw(G)
plt.show()
plt.savefig("C:\\Users\\Toshiba\\ijaz\\centrality_files\\diagrams\\Eigenvector.png")

# %%
import pandas as pd
import networkx as nx

# Load the dataset
df = pd.read_excel(file)

# Create a NetworkX graph
G = nx.from_pandas_edgelist(df, source='col1', target='col2')


# Calculate and print the local centrality (degree centrality)
centrality_measures = nx.degree_centrality(G)
print("Local Centrality (Degree Centrality):", centrality_measures)
# centrality_measures

df = pd.DataFrame(list(centrality_measures.items()), columns=['col1', 'col2'])

# Display the DataFrame
df.to_excel('C:\\Users\\Toshiba\\ijaz\\centrality_files\\Local_Centrality.xlsx')

# %%
# importing networkx
import networkx as nx
# importing matplotlib.pyplot
import matplotlib.pyplot as plt
import xlrd

file ="C:\\Users\\Toshiba\\ijaz\\centrality_files\\Local_Centrality.xls"


G=nx.Graph()

names=[]

book= xlrd.open_workbook(file)

sheet = book.sheet_by_index(0)

for row in range(sheet.nrows):
    data = sheet.row_slice(row)
    
    person1 = data[0].value
    person2 = data[1].value
    
    names.append((person1, person2))

G.add_edges_from(names)

nx.draw(G)
plt.show()
plt.savefig("C:\\Users\\Toshiba\\ijaz\\centrality_files\\diagrams\\Local_Centrality.png")
